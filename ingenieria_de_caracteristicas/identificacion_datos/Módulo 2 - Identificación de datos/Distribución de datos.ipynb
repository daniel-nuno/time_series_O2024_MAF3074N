# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

LW=load_wine()
data=LW.data
names=LW.feature_names
df=pd.DataFrame(data=data,columns=names)
df.head()
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %% [markdown]
# # Histográmas

# %%
plt.hist(df['alcohol'])
plt.grid()

# %%
df['alcohol'].hist()

# %%
# Representación de matplotlib
plt.hist(df)
plt.grid()

# %%
# Representación de DataFrame
H=df.hist(figsize=(13,10))

# %% [markdown]
# # Medidas de posición

# %%
# Media aritmética
np.mean(df['alcohol'])
# Out:
# 13.000617977528083

# %%
df['alcohol'].mean()
# Out:
# 13.000617977528083

# %%
df.mean()
# Out:
# alcohol                          13.000618
# malic_acid                        2.336348
# ash                               2.366517
# alcalinity_of_ash                19.494944
# magnesium                        99.741573
# total_phenols                     2.295112
# flavanoids                        2.029270
# nonflavanoid_phenols              0.361854
# proanthocyanins                   1.590899
# color_intensity                   5.058090
# hue                               0.957449
# od280/od315_of_diluted_wines      2.611685
# proline                         746.893258
# dtype: float64

# %%
from scipy import stats

# %%
# Media recortada
stats.trim_mean(df['alcohol'],0.1) # Especificando porcentaje a eliminar de los extremos
# Out:
# 13.006388888888889

# %%
stats.tmean(df['alcohol'],(12,14)) # Especificando valores concretos en donde hacer el corte
# Out:
# 12.983576642335766

# %%
# Media ponderada
#
np.average(df['alcohol']) # Sin argumento adicional calcula la media aritmética
# Out:
# 13.00061797752809

# %%
# Dimensión de la variable
df.shape
# Out:
# (178, 13)

# %%
# Escogiendo la ponderación
a=1e-3
idx=np.linspace(0,177,178)

# %%
w=np.exp(-a*idx)
min(w)
# Out:
# 0.8377797845229938

# %%
# Grafica de la asignación de pesos
plt.plot(idx,w)
plt.grid()

# %%
np.average(df['alcohol'],weights=w)
# Out:
# 13.016280273538646

# %%
df.alcohol[0] # Entonces debe ser mayor que la media aritmética
# Out:
# 14.23

# %%
# Media geométrica
stats.gmean(df['alcohol'])
# Out:
# 12.975278352602606

# %%
# Media armónica
stats.hmean(df['alcohol'])
# Out:
# 12.949820740397149

# %%
# Mediana
np.median(df['alcohol'])
# Out:
# 13.05

# %%
df.alcohol.median()
# Out:
# 13.05

# %%
# Cuantiles o percentiles
np.quantile(df['alcohol'],0.5) # Mediana
# Out:
# 13.05

# %%
np.quantile(df['alcohol'],0.1) # Primer decíl
# Out:
# 11.933000000000002

# %%
np.percentile(df['alcohol'],25) # Primer cuartíl
# Out:
# 12.362499999999999

# %%
df['alcohol'].quantile(0.75) # Tercer cuartíl
# Out:
# 13.6775

# %%
# Moda
df['alcohol'].mode()
# Out:
# 0    12.37
# 1    13.05
# dtype: float64

# %%
stats.mode(df['alcohol'])
# Out:
# ModeResult(mode=array([12.37]), count=array([6]))

# %% [markdown]
# # Mediadas de disperción

# %%
# Varianza y desviación estandar
np.var(df) # varianza
# Out:
# alcohol                             0.655360
# malic_acid                          1.241004
# ash                                 0.074842
# alcalinity_of_ash                  11.090031
# magnesium                         202.843328
# total_phenols                       0.389489
# flavanoids                          0.992114
# nonflavanoid_phenols                0.015402
# proanthocyanins                     0.325754
# color_intensity                     5.344256
# hue                                 0.051951
# od280/od315_of_diluted_wines        0.501254
# proline                         98609.600966
# dtype: float64

# %%
np.std(df) # Desviación
# Out:
# alcohol                           0.809543
# malic_acid                        1.114004
# ash                               0.273572
# alcalinity_of_ash                 3.330170
# magnesium                        14.242308
# total_phenols                     0.624091
# flavanoids                        0.996049
# nonflavanoid_phenols              0.124103
# proanthocyanins                   0.570749
# color_intensity                   2.311765
# hue                               0.227929
# od280/od315_of_diluted_wines      0.707993
# proline                         314.021657
# dtype: float64

# %%
np.sqrt(np.var(df))
# Out:
# alcohol                           0.809543
# malic_acid                        1.114004
# ash                               0.273572
# alcalinity_of_ash                 3.330170
# magnesium                        14.242308
# total_phenols                     0.624091
# flavanoids                        0.996049
# nonflavanoid_phenols              0.124103
# proanthocyanins                   0.570749
# color_intensity                   2.311765
# hue                               0.227929
# od280/od315_of_diluted_wines      0.707993
# proline                         314.021657
# dtype: float64

# %%
# Varianza no sesgada
df.var()
# Out:
# alcohol                             0.659062
# malic_acid                          1.248015
# ash                                 0.075265
# alcalinity_of_ash                  11.152686
# magnesium                         203.989335
# total_phenols                       0.391690
# flavanoids                          0.997719
# nonflavanoid_phenols                0.015489
# proanthocyanins                     0.327595
# color_intensity                     5.374449
# hue                                 0.052245
# od280/od315_of_diluted_wines        0.504086
# proline                         99166.717355
# dtype: float64

# %%
df.std()
# Out:
# alcohol                           0.811827
# malic_acid                        1.117146
# ash                               0.274344
# alcalinity_of_ash                 3.339564
# magnesium                        14.282484
# total_phenols                     0.625851
# flavanoids                        0.998859
# nonflavanoid_phenols              0.124453
# proanthocyanins                   0.572359
# color_intensity                   2.318286
# hue                               0.228572
# od280/od315_of_diluted_wines      0.709990
# proline                         314.907474
# dtype: float64

# %% [markdown]
# Modificando el grado de libertad de $\delta$ en la varianza no sesgada
# $$
# s^2=\frac{1}{n-\delta}\sum_{i=1}^n(x_i-\bar{x})^2,
# $$
# donde $\bar{x}$ es la media aritmética de la muestra.

# %%
# Varianza
df['alcohol'].var(ddof=0)
# Out:
# 0.6553597304633259

# %%
# Rango
m=min(df['alcohol'])
m
# Out:
# 11.03

# %%
M=max(df['alcohol'])
M
# Out:
# 14.83

# %%
M-m
# Out:
# 3.8000000000000007

# %%
m=df.min()
M=df.max()
M-m
# Out:
# alcohol                            3.80
# malic_acid                         5.06
# ash                                1.87
# alcalinity_of_ash                 19.40
# magnesium                         92.00
# total_phenols                      2.90
# flavanoids                         4.74
# nonflavanoid_phenols               0.53
# proanthocyanins                    3.17
# color_intensity                   11.72
# hue                                1.23
# od280/od315_of_diluted_wines       2.73
# proline                         1402.00
# dtype: float64

# %%
# Rango intercuartílico
q1=df.quantile(0.25)
q3=df.quantile(0.75)
q3-q1
# Out:
# alcohol                           1.3150
# malic_acid                        1.4800
# ash                               0.3475
# alcalinity_of_ash                 4.3000
# magnesium                        19.0000
# total_phenols                     1.0575
# flavanoids                        1.6700
# nonflavanoid_phenols              0.1675
# proanthocyanins                   0.7000
# color_intensity                   2.9800
# hue                               0.3375
# od280/od315_of_diluted_wines      1.2325
# proline                         484.5000
# dtype: float64

# %%
stats.iqr(df['alcohol'])
# Out:
# 1.3150000000000013

# %%
# Coeficiente de variación (Pearson)
stats.variation(df['alcohol'])
# Out:
# 0.062269571794804905

# %%
np.std(df['alcohol'])/np.abs(np.mean(df['alcohol']))
# Out:
# 0.062269571794804954

# %%
H=df.hist(figsize=(15,9))

# %%
df[['alcalinity_of_ash','color_intensity']].std()
# Out:
# alcalinity_of_ash    3.339564
# color_intensity      2.318286
# dtype: float64

# %%
df[['alcalinity_of_ash','color_intensity']].mean()
# Out:
# alcalinity_of_ash    19.494944
# color_intensity       5.058090
# dtype: float64

# %%
df[['alcalinity_of_ash','color_intensity']].std()/_ # _ se refiere al último valor mostrado
# Out:
# alcalinity_of_ash    0.171304
# color_intensity      0.458332
# dtype: float64

# %% [markdown]
# # Medidas de forma

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine

LW=load_wine()
df=pd.DataFrame(LW.data,columns=LW.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %%
# Coeficiente de Fisher (Simetría)
df['alcohol'].skew()
# Out:
# -0.051482331077134784

# %%
df['malic_acid'].skew()
# Out:
# 1.0396511925814442

# %%
df['ash'].skew()
# Out:
# -0.17669931645735712

# %%
df.skew()
# Out:
# alcohol                        -0.051482
# malic_acid                      1.039651
# ash                            -0.176699
# alcalinity_of_ash               0.213047
# magnesium                       1.098191
# total_phenols                   0.086639
# flavanoids                      0.025344
# nonflavanoid_phenols            0.450151
# proanthocyanins                 0.517137
# color_intensity                 0.868585
# hue                             0.021091
# od280/od315_of_diluted_wines   -0.307285
# proline                         0.767822
# dtype: float64

# %%
H=df.hist(figsize=(12,8))

# %%
# Curtosis o apuntamiento
df.kurt() # Se hace una referencia interna sobre la curtosis de la Normal (3)
# Out:
# alcohol                        -0.852500
# malic_acid                      0.299207
# ash                             1.143978
# alcalinity_of_ash               0.487942
# magnesium                       2.104991
# total_phenols                  -0.835627
# flavanoids                     -0.880382
# nonflavanoid_phenols           -0.637191
# proanthocyanins                 0.554649
# color_intensity                 0.381522
# hue                            -0.344096
# od280/od315_of_diluted_wines   -1.086435
# proline                        -0.248403
# dtype: float64
